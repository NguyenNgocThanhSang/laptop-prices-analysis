# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Dataset/laptop.csv')
df
# Out:
#       Unnamed: 0    Brand                                               Name  \
# 0              0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...
# 1              1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....
# 2              3     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...
# 3              4       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...
# 4              6  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...
# ...          ...      ...                                                ...
# 3971        4403     ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...
# 3972        4404     ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...
# 3973        4405     ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...
# 3974        4407     ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...
# 3975        4408   Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...
#
#       Price            Processor_Name Processor_Brand     RAM_Expandable  \
# 0     22990        MediaTek Octa-core        MediaTek     Not Expandable
# 1     36289     AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable
# 2     78500  Intel Core i5 (12th Gen)           Intel   32 GB Expandable
# 3     55490  Intel Core i5 (12th Gen)           Intel    8 GB Expandable
# 4     21990  Intel Core i3 (11th Gen)           Intel     Not Expandable
# ...     ...                       ...             ...                ...
# 3971  84990   Intel Core i5 (8th Gen)           Intel   32 GB Expandable
# 3972  40031  Intel Core i3 (11th Gen)           Intel     Not Expandable
# 3973  75990     AMD Octa-Core Ryzen 7             AMD     Not Expandable
# 3974  71909     AMD Quad-Core Ryzen 5             AMD   32 GB Expandable
# 3975  69990  Intel Core i5 (10th Gen)           Intel     Not Expandable
#
#           RAM      RAM_TYPE                 Ghz Display_type Display  \
# 0       4 GB       DDR4 RAM   2.0 Ghz Processor          LED   11.6
# 1       8 GB      DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2      16 GB      DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3       8 GB      DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4     8 GB LP   LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
# ...       ...           ...                 ...          ...     ...
# 3971    8 GB      DDR4 RAM    1.6 Ghz Processor          LED     14
# 3972    8 GB       DDR4 RAM   4.0 Ghz Processor          LED   15.6
# 3973   16 GB       DDR4 RAM   3.1 Ghz Processor          LED   15.6
# 3974    8 GB      DDR4 RAM    2.1 Ghz Processor          LED   15.6
# 3975    8 GB       DDR4 RAM   2.5 Ghz Processor          LED   15.6
#
#                              GPU GPU_Brand                  SSD     HDD  \
# 0            Integrated Graphics  MediaTek    64 GB SSD Storage  No HDD
# 1                         Radeon       AMD   512 GB SSD Storage  No HDD
# 2     GeForce RTX 3050 GPU, 4 GB    NVIDIA   512 GB SSD Storage  No HDD
# 3                        Iris Xe     Intel   512 GB SSD Storage  No HDD
# 4                            UHD     Intel   512 GB SSD Storage  No HDD
# ...                          ...       ...                  ...     ...
# 3971     Geforce MX150 GPU, 2 GB    NVIDIA   512 GB SSD Storage  No HDD
# 3972                         UHD     Intel   256 GB SSD Storage  No HDD
# 3973  GeForce RTX 3050 GPU, 4 GB    NVIDIA  1024 GB SSD Storage  No HDD
# 3974  GeForce GTX 1650 GPU, 4 GB    NVIDIA   512 GB SSD Storage  No HDD
# 3975  Geforce GTX 1650 GPU, 4 GB    NVIDIA   512 GB SSD Storage  No HDD
#
#      Adapter                Battery_Life
# 0         45    Upto 12 Hrs Battery Life
# 1         65    Upto 11 Hrs Battery Life
# 2         56    Upto 10 Hrs Battery Life
# 3         no  Upto 7.30 Hrs Battery Life
# 4         45     Upto 8 Hrs Battery Life
# ...      ...                         ...
# 3971      65     Upto 9 Hrs Battery Life
# 3972      65     Upto 3 Hrs Battery Life
# 3973     120     Upto 3 Hrs Battery Life
# 3974     150                150W Adapter
# 3975      60                 60W Adapter
#
# [3976 rows x 18 columns]

# %%
df['Display'].unique()
# Out:
# array(['11.6 ', '15.6 ', '14 ', '16 ', '17.3 ', '13.3 ', '16.1 ', '13.6 ',
#        '14.2 ', '14.1 ', '15.3 ', '13.4 ', '15 ', '10.5 ', '13.5 ', '13 ',
#        '12.4 ', '16.2 ', 'OLED Display With Touchscreen', '14.0 ', '17 ',
#        '18 ', '14.5 ', '12 ', '10.1 ', '15. ', '14.9 ', '11 ', '12.3 ',
#        '16.6 ', '12.2 ', '12.5 ', '15.4 ', '12.0 '], dtype=object)

# %%
df['Ghz'].unique()
# Out:
# array([' 2.0 Ghz Processor', ' 4.0 Ghz Processor', ' 3.3 Ghz Processor',
#        ' 4.2 Ghz Processor', ' 1.7 Ghz Processor', '0',
#        ' 2.5 Ghz Processor', ' 2.2 Ghz Processor', ' 2.9 Ghz Processor',
#        ' 3.4 Ghz Processor', ' 2.6 Ghz Processor', ' 3.0 Ghz Processor',
#        ' 4.7 Ghz Processor', ' 3.1 Ghz Processor', ' 2.7 Ghz Processor',
#        ' 2.8 Ghz Processor', ' 2.4 Ghz Processor', ' 2.1 Ghz Processor',
#        ' 4.8 Ghz Processor', ' 1.2 Ghz Processor', ' 1.0 Ghz Processor',
#        ' 1.8 Ghz Processor', ' 1.1 Ghz Processor', ' 2.3 Ghz Processor',
#        ' 1.6 Ghz Processor', ' 0.8 Ghz Processor', ' 1.3 Ghz Processor',
#        ' 1.5 Ghz Processor', ' 1.9 Ghz Processor', ' 5.5 Ghz Processor',
#        ' 1.4 Ghz Processor'], dtype=object)

# %%
df['Display'].value_counts()
# Out:
# Display
# 15.6                             2205
# 14                                997
# 16                                229
# 13.3                              163
# 17.3                               99
# 16.1                               64
# 11.6                               41
# 15                                 23
# 13.4                               19
# 13                                 17
# 13.5                               15
# 17                                 13
# 14.1                               12
# 14.0                                9
# 10.1                                8
# 12.3                                8
# 15.3                                7
# 14.5                                6
# 18                                  6
# 16.2                                5
# 12.4                                5
# 14.2                                5
# 15.                                 3
# 13.6                                3
# 15.4                                3
# 12                                  2
# 12.2                                2
# OLED Display With Touchscreen       1
# 10.5                                1
# 14.9                                1
# 11                                  1
# 16.6                                1
# 12.5                                1
# 12.0                                1
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# Brand              object
# Name               object
# Price               int64
# Processor_Name     object
# Processor_Brand    object
# RAM_Expandable     object
# RAM                object
# RAM_TYPE           object
# Ghz                object
# Display_type       object
# Display            object
# GPU                object
# GPU_Brand          object
# SSD                object
# HDD                object
# Adapter            object
# Battery_Life       object
# dtype: object

# %%
df['GPU'].value_counts()
# Out:
# GPU
# UHD                           651
# Iris Xe                       573
# Radeon                        313
# GeForce RTX 3050 GPU, 4 GB    203
# Integrated                    156
#                              ...
# Quadro T550 GPU, 4 GB           1
# UHD GPU, 2 GB                   1
# Integrated GPU, 512 MB          1
# Radeon RX 6650M GPU, 8 GB       1
# Radeon HD 8210 GPU, 2 GB        1
# Name: count, Length: 300, dtype: int64

# %%
df['Adapter'].unique()
# Out:
# array(['45', '65', '56', 'no', '150', '170', '230', '135', '41', '100',
#        '90', '120', '96', '180', '63', '30', '54', '33', '46', '67', '57',
#        '43', '48', '70', '37', '24', '42', '330', '200', '58', '240',
#        '50', '280', '60', '80', '35', '51', '61', '76', '38', '86', '66',
#        '210', '39', '97', '140', '83', '59', '53', '71', '75', '74', '49',
#        '300', '68', '52', '40', '36', '32', '15', '26', '47', '64', '130',
#        '87', '72', '95', '69'], dtype=object)

# %%
df['Battery_Life'].value_counts()
# Out:
# Battery_Life
# 65W Adapter                     803
# 45W Adapter                     287
#  Upto 6 Hrs Battery Life        199
#  Upto 8 Hrs Battery Life        151
#  Upto 10 Hrs Battery Life       144
#                                ...
# Upto 10.8 Hrs Battery Life        1
#  Upto 16.30 Hrs Battery Life      1
#  Upto 9.3 Hrs Battery Life        1
# 87W Adapter                       1
# 71W Adapter                       1
# Name: count, Length: 191, dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0           0
# Brand                0
# Name                 0
# Price                0
# Processor_Name       0
# Processor_Brand      0
# RAM_Expandable       0
# RAM                  0
# RAM_TYPE             0
# Ghz                  0
# Display_type         0
# Display              0
# GPU                  8
# GPU_Brand            4
# SSD                  0
# HDD                  0
# Adapter              0
# Battery_Life       418
# dtype: int64

# %% [markdown]
# ### xem toàn bộ dữ liệu

# %%
# bỏ cột đầu, cột đầu không có nghĩa
df.drop(df.columns[0], axis=1, inplace=True)
df
# Out:
#         Brand                                               Name  Price  \
# 0          HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...  22990
# 1      Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....  36289
# 2        Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...  78500
# 3          HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...  55490
# 4     Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...  21990
# ...       ...                                                ...    ...
# 3971     ASUS  ASUS Zenbook UX430UN-GV022T Laptop (14 Inch | ...  84990
# 3972     ASUS  ASUS Vivobook K15 OLED K513EA-L301WS Laptop (1...  40031
# 3973     ASUS  ASUS VivoBook Pro 15 OLED M3500QC-L1711WS Lapt...  75990
# 3974     ASUS  ASUS TUF FX505DT-AL118T Laptop (15.6 Inch | AM...  71909
# 3975   Lenovo  Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inc...  69990
#
#                 Processor_Name Processor_Brand     RAM_Expandable      RAM  \
# 0           MediaTek Octa-core        MediaTek     Not Expandable    4 GB
# 1        AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable    8 GB
# 2     Intel Core i5 (12th Gen)           Intel   32 GB Expandable   16 GB
# 3     Intel Core i5 (12th Gen)           Intel    8 GB Expandable    8 GB
# 4     Intel Core i3 (11th Gen)           Intel     Not Expandable  8 GB LP
# ...                        ...             ...                ...      ...
# 3971   Intel Core i5 (8th Gen)           Intel   32 GB Expandable    8 GB
# 3972  Intel Core i3 (11th Gen)           Intel     Not Expandable    8 GB
# 3973     AMD Octa-Core Ryzen 7             AMD     Not Expandable   16 GB
# 3974     AMD Quad-Core Ryzen 5             AMD   32 GB Expandable    8 GB
# 3975  Intel Core i5 (10th Gen)           Intel     Not Expandable    8 GB
#
#           RAM_TYPE                 Ghz Display_type Display  \
# 0         DDR4 RAM   2.0 Ghz Processor          LED   11.6
# 1        DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2        DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3        DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4      LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
# ...            ...                 ...          ...     ...
# 3971     DDR4 RAM    1.6 Ghz Processor          LED     14
# 3972      DDR4 RAM   4.0 Ghz Processor          LED   15.6
# 3973      DDR4 RAM   3.1 Ghz Processor          LED   15.6
# 3974     DDR4 RAM    2.1 Ghz Processor          LED   15.6
# 3975      DDR4 RAM   2.5 Ghz Processor          LED   15.6
#
#                              GPU GPU_Brand                  SSD     HDD  \
# 0            Integrated Graphics  MediaTek    64 GB SSD Storage  No HDD
# 1                         Radeon       AMD   512 GB SSD Storage  No HDD
# 2     GeForce RTX 3050 GPU, 4 GB    NVIDIA   512 GB SSD Storage  No HDD
# 3                        Iris Xe     Intel   512 GB SSD Storage  No HDD
# 4                            UHD     Intel   512 GB SSD Storage  No HDD
# ...                          ...       ...                  ...     ...
# 3971     Geforce MX150 GPU, 2 GB    NVIDIA   512 GB SSD Storage  No HDD
# 3972                         UHD     Intel   256 GB SSD Storage  No HDD
# 3973  GeForce RTX 3050 GPU, 4 GB    NVIDIA  1024 GB SSD Storage  No HDD
# 3974  GeForce GTX 1650 GPU, 4 GB    NVIDIA   512 GB SSD Storage  No HDD
# 3975  Geforce GTX 1650 GPU, 4 GB    NVIDIA   512 GB SSD Storage  No HDD
#
#      Adapter                Battery_Life
# 0         45    Upto 12 Hrs Battery Life
# 1         65    Upto 11 Hrs Battery Life
# 2         56    Upto 10 Hrs Battery Life
# 3         no  Upto 7.30 Hrs Battery Life
# 4         45     Upto 8 Hrs Battery Life
# ...      ...                         ...
# 3971      65     Upto 9 Hrs Battery Life
# 3972      65     Upto 3 Hrs Battery Life
# 3973     120     Upto 3 Hrs Battery Life
# 3974     150                150W Adapter
# 3975      60                 60W Adapter
#
# [3976 rows x 17 columns]

# %%
# kiểm ta các dòng bị trùng lặp
df[df.duplicated()]
# Out:
#        Brand                                               Name  Price  \
# 2867  Lenovo  Lenovo Ideapad 3 15ITL6 (82H801L7IN) Laptop (1...  33900
# 3018      HP  HP 15s-du1044tu (18N71PA) Laptop (15.6 Inch | ...  22071
# 3104    Acer  Acer Aspire 5 A514-53 (NX.HZ6SI.001) Laptop (1...  27775
# 3321  Lenovo  Lenovo Ideapad Gaming 3 15ACH6 (82K200X3IN) La...  81990
#
#                 Processor_Name Processor_Brand     RAM_Expandable     RAM  \
# 2867  Intel Core i3 (11th Gen)           Intel   12 GB Expandable   8 GB
# 3018   Intel Celeron Dual-Core           Intel     Not Expandable   4 GB
# 3104  Intel Core i3 (10th Gen)           Intel   12 GB Expandable   4 GB
# 3321     AMD Octa-Core Ryzen 7             AMD   16 GB Expandable  16 GB
#
#         RAM_TYPE                 Ghz Display_type Display  \
# 2867   DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 3018    DDR4 RAM   1.1 Ghz Processor          LED   15.6
# 3104   DDR4 RAM    1.2 Ghz Processor          LED     14
# 3321   DDR4 RAM    3.1 Ghz Processor          LCD   15.6
#
#                              GPU GPU_Brand                 SSD  \
# 2867                         UHD     Intel  512 GB SSD Storage
# 3018                     UHD 600     Intel              NO SSD
# 3104                         UHD     Intel  512 GB SSD Storage
# 3321  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage
#
#                       HDD Adapter               Battery_Life
# 2867               No HDD      45   Upto 12 Hrs Battery Life
# 3018  1024 GB HDD Storage      46                46W Adapter
# 3104               No HDD      48   Upto 11 Hrs Battery Life
# 3321               No HDD      65    Upto 5 Hrs Battery Life

# %%
# đếm giá trị bị khuyết
df.isnull().sum()
# Out:
# Brand                0
# Name                 0
# Price                0
# Processor_Name       0
# Processor_Brand      0
# RAM_Expandable       0
# RAM                  0
# RAM_TYPE             0
# Ghz                  0
# Display_type         0
# Display              0
# GPU                  8
# GPU_Brand            4
# SSD                  0
# HDD                  0
# Adapter              0
# Battery_Life       418
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3976 entries, 0 to 3975
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            3976 non-null   object
#  1   Name             3976 non-null   object
#  2   Price            3976 non-null   int64
#  3   Processor_Name   3976 non-null   object
#  4   Processor_Brand  3976 non-null   object
#  5   RAM_Expandable   3976 non-null   object
#  6   RAM              3976 non-null   object
#  7   RAM_TYPE         3976 non-null   object
#  8   Ghz              3976 non-null   object
#  9   Display_type     3976 non-null   object
#  10  Display          3976 non-null   object
#  11  GPU              3968 non-null   object
#  12  GPU_Brand        3972 non-null   object
#  13  SSD              3976 non-null   object
#  14  HDD              3976 non-null   object
#  15  Adapter          3976 non-null   object
#  16  Battery_Life     3558 non-null   object
# dtypes: int64(1), object(16)
# memory usage: 528.2+ KB

# %%
# xem tên các cột
df.columns
# Out:
# Index(['Brand', 'Name', 'Price', 'Processor_Name', 'Processor_Brand',
#        'RAM_Expandable', 'RAM', 'RAM_TYPE', 'Ghz', 'Display_type', 'Display',
#        'GPU', 'GPU_Brand', 'SSD', 'HDD', 'Adapter', 'Battery_Life'],
#       dtype='object')

# %% [markdown]
# ### xem từng cột dữ liệu

# %%
df['Brand'].value_counts()
# Out:
# Brand
# ASUS         989
# Lenovo       811
# HP           803
# Dell         420
# Acer         322
# MSI          316
# Samsung       61
# Apple         49
# Infinix       39
# Microsoft     34
# AVITA         23
# Gigabyte      17
# LG            15
# Honor         14
# iball         11
# Xiaomi        10
# Fujitsu        8
# Zebronics      8
# Wings          4
# Realme         3
# Coconics       3
# Micromax       3
# Colorful       3
# Tecno          2
# Smartron       2
# Razer          1
# Huawei         1
# Lava           1
# VAIO           1
# Nokia          1
# RDP            1
# Name: count, dtype: int64

# %%
df['Name'].value_counts()
# Out:
# Name
# Samsung Galaxy Book Pro Intel Evo NP940XFG-KC5IN 3 Pro NP940XFG-KC5IN Laptop (14 Inch | Core i7 13th Gen | 16 GB | Windows 11 | 1 TB SSD)::599446::computer::laptops    2
# Lenovo Ideapad Gaming 3 15IHU6 (82K101EEIN) Laptop (15.6 Inch | Core i5 11th Gen | 8 GB | Windows 11 | 512 GB SSD)::597645::computer::laptops                           2
# HP Pavilion 14-dv1029TU (5D0C2PA) Laptop (14 Inch | Core i7 11th Gen | 16 GB | Windows 11 | 1 TB SSD)::595979::computer::laptops                                        2
# HP Victus 15-FA1333TX (9Y0Z2PA) Laptop (15.6 Inch | Core i7 13th Gen | 16 GB | Windows 11 | 1 TB SSD)::618538::computer::laptops                                        2
# Samsung Galaxy Book 3 Pro NP940XFG-KC1IN Laptop (14 Inch | Core i5 13th Gen | 16 GB | Windows 11 | 512 GB SSD)::599455::computer::laptops                               2
#                                                                                                                                                                        ..
# ASUS ROG Zephyrus G14 GA402RJZ-L4134WS Laptop (14 Inch | AMD Octa Core Ryzen 7 | 16 GB | Windows 11 | 1 TB SSD)::596426::computer::laptops                              1
# Lenovo E41-55 (82FJ00ABIH) Laptop (14 Inch | AMD Dual Core Athlon | 4 GB | Windows 10 | 1 TB HDD)::595927::computer::laptops                                            1
# ASUS VivoBook 15 X515MA-BR101W Laptop (15.6 Inch | Intel Pentium Quad Core | 4 GB | Windows 11 | 1 TB HDD)::599366::computer::laptops                                   1
# Microsoft Surface Go 2 (8QF-00046) Laptop (12.4 Inch | Core i5 11th Gen | 8 GB | Windows 11 | 256 GB SSD)::596159::computer::laptops                                    1
# Lenovo Legion 5i (82AU00CFIN) Laptop (15.6 Inch | Core i5 10th Gen | 8 GB | Windows 10 | 512 GB SSD)::581543::computer::laptops                                         1
# Name: count, Length: 3941, dtype: int64

# %%
df['Price'].describe()
# Out:
# count      3976.000000
# mean      72432.528672
# std       52207.650948
# min        7990.000000
# 25%       39873.250000
# 50%       58990.000000
# 75%       84990.000000
# max      503890.000000
# Name: Price, dtype: float64

# %%
df['Processor_Name'].value_counts()
# Out:
# Processor_Name
# Intel Core i5 (11th Gen)          316
# Intel Core i5 (12th Gen)          294
# AMD Hexa-Core Ryzen 5             245
# AMD Octa-Core Ryzen 7             239
# Intel Core i3 (11th Gen)          189
#                                  ...
# Intel Core i9 (8th Gen)             1
# 1.6 Ghz Processor                   1
# Apple M1 Pro                        1
# AMD Dual-Core Athlon Processor      1
# 2.6 Ghz Processor                   1
# Name: count, Length: 125, dtype: int64

# %%
df['Processor_Brand'].value_counts()
# Out:
# Processor_Brand
# Intel        3009
# AMD           920
# Apple          20
# MediaTek        4
# 1.7             4
# 2.1             2
# 2.0             2
# 3.0             2
# 2.4             2
# 3.4             2
# 1.6             1
# 3.3             1
# 2.2             1
# Qualcomm        1
# 2.3             1
# 1.8             1
# Microsoft       1
# 1.9             1
# 2.6             1
# Name: count, dtype: int64
